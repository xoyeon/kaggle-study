# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('/kaggle/input/titanic/train.csv')
df_test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %% [markdown]
# Fill Null in Age

# %%
df_train['Initial'] = df_train['Name'].str.extract('([A-Za-z]+)\.')
df_test['Initial'] = df_test['Name'].str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_cfafb_row0_col0, #T_cfafb_row0_col1, #T_cfafb_row0_col3, #T_cfafb_row0_col4, #T_cfafb_row0_col5, #T_cfafb_row0_col7, #T_cfafb_row0_col8, #T_cfafb_row0_col12, #T_cfafb_row0_col15, #T_cfafb_row0_col16, #T_cfafb_row1_col2, #T_cfafb_row1_col6, #T_cfafb_row1_col9, #T_cfafb_row1_col10, #T_cfafb_row1_col11, #T_cfafb_row1_col13, #T_cfafb_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_cfafb_row0_col2, #T_cfafb_row0_col6, #T_cfafb_row0_col9, #T_cfafb_row0_col10, #T_cfafb_row0_col11, #T_cfafb_row0_col13, #T_cfafb_row0_col14, #T_cfafb_row1_col0, #T_cfafb_row1_col1, #T_cfafb_row1_col3, #T_cfafb_row1_col4, #T_cfafb_row1_col5, #T_cfafb_row1_col7, #T_cfafb_row1_col8, #T_cfafb_row1_col12, #T_cfafb_row1_col15, #T_cfafb_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cfafb_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th class="col_heading level0 col0" >Capt</th>
#       <th class="col_heading level0 col1" >Col</th>
#       <th class="col_heading level0 col2" >Countess</th>
#       <th class="col_heading level0 col3" >Don</th>
#       <th class="col_heading level0 col4" >Dr</th>
#       <th class="col_heading level0 col5" >Jonkheer</th>
#       <th class="col_heading level0 col6" >Lady</th>
#       <th class="col_heading level0 col7" >Major</th>
#       <th class="col_heading level0 col8" >Master</th>
#       <th class="col_heading level0 col9" >Miss</th>
#       <th class="col_heading level0 col10" >Mlle</th>
#       <th class="col_heading level0 col11" >Mme</th>
#       <th class="col_heading level0 col12" >Mr</th>
#       <th class="col_heading level0 col13" >Mrs</th>
#       <th class="col_heading level0 col14" >Ms</th>
#       <th class="col_heading level0 col15" >Rev</th>
#       <th class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfafb_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_cfafb_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_cfafb_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_cfafb_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_cfafb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cfafb_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_cfafb_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_cfafb_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_cfafb_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_cfafb_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_cfafb_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_cfafb_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_cfafb_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_cfafb_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_cfafb_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_cfafb_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_cfafb_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_cfafb_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cfafb_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_cfafb_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_cfafb_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_cfafb_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_cfafb_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_cfafb_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_cfafb_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_cfafb_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_cfafb_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_cfafb_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_cfafb_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_cfafb_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_cfafb_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_cfafb_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_cfafb_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_cfafb_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_cfafb_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_cfafb_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
                            ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr','Mr'],inplace=True)
df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
                            ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr','Mr'],inplace=True)

# %%
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Initial
# Master    414.975000  0.575000  2.625000   4.574167  2.300000  1.375000
# Miss      411.741935  0.704301  2.284946  21.860000  0.698925  0.537634
# Mr        455.880907  0.162571  2.381853  32.739609  0.293006  0.151229
# Mrs       456.393701  0.795276  1.984252  35.981818  0.692913  0.818898
# Other     564.444444  0.111111  1.666667  45.888889  0.111111  0.111111
#
#               Fare
# Initial
# Master   34.703125
# Miss     43.937188
# Mr       24.939822
# Mrs      45.420603
# Other    19.102778

# %%
df_train.groupby('Initial')['Survived'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Initial'>

# %%
df_all = pd.concat([df_train, df_test])

# %%
df_all.reset_index(drop=True)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked Initial
# 0         0           A/5 21171    7.2500   NaN        S      Mr
# 1         0            PC 17599   71.2833   C85        C     Mrs
# 2         0    STON/O2. 3101282    7.9250   NaN        S    Miss
# 3         0              113803   53.1000  C123        S     Mrs
# 4         0              373450    8.0500   NaN        S      Mr
# ...     ...                 ...       ...   ...      ...     ...
# 1304      0           A.5. 3236    8.0500   NaN        S      Mr
# 1305      0            PC 17758  108.9000  C105        C      Mr
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S      Mr
# 1307      0              359309    8.0500   NaN        S      Mr
# 1308      1                2668   22.3583   NaN        C  Master
#
# [1309 rows x 13 columns]

# %%
df_all.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Initial
# Master    658.852459  0.575000  2.655738   5.482642  2.049180  1.377049
# Miss      616.992453  0.704301  2.332075  21.834533  0.652830  0.494340
# Mr        658.831388  0.162571  2.359274  32.556397  0.286641  0.159533
# Mrs       685.673367  0.795276  1.929648  37.034884  0.658291  0.824121
# Other     714.923077  0.111111  1.615385  44.923077  0.230769  0.153846
#
#               Fare
# Initial
# Master   36.008195
# Miss     42.667628
# Mr       25.316303
# Mrs      50.686244
# Other    35.919231

# %%
df_train.loc[df_train['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Initial
# 1        0          PC 17599  71.2833   C85        C     Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3        0            113803  53.1000  C123        S     Mrs
# 8        2            347742  11.1333   NaN        S     Mrs
# 9        0            237736  30.0708   NaN        C     Mrs
# ..     ...               ...      ...   ...      ...     ...
# 875      0              2667   7.2250   NaN        C    Miss
# 879      1             11767  83.1583   C50        C     Mrs
# 880      1            230433  26.0000   NaN        S     Mrs
# 887      0            112053  30.0000   B42        S    Miss
# 889      0            111369  30.0000  C148        C      Mr
#
# [342 rows x 13 columns]

# %%
df_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Mr'), 'Age'] = 30
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Mrs'), 'Age'] = 37
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Master'), 'Age'] = 5
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Miss'), 'Age'] = 22
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Other'), 'Age'] = 45

df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Mr'), 'Age'] = 30
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Mrs'), 'Age'] = 37
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Master'), 'Age'] = 5
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Miss'), 'Age'] = 22
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Other'), 'Age'] = 45

# %%
df_train.loc[(df_train['Initial'] == 'Mr'), 'Age']
# Out:
# 0      22.0
# 4      35.0
# 5      30.0
# 6      54.0
# 12     20.0
#        ...
# 881    33.0
# 883    28.0
# 884    25.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 529, dtype: float64

# %%
df_train['Age'].isnull().sum()
# Out:
# 0
