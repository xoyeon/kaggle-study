# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('/kaggle/input/titanic/train.csv')
df_test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %% [markdown]
# 2.2 Sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6af1d_row0_col0, #T_6af1d_row0_col2, #T_6af1d_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6af1d_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_6af1d_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_6af1d_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_6af1d_row2_col0, #T_6af1d_row2_col1, #T_6af1d_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6af1d_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6af1d_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_6af1d_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_6af1d_row0_col1" class="data row0 col1" >233</td>
#       <td id="T_6af1d_row0_col2" class="data row0 col2" >314</td>
#     </tr>
#     <tr>
#       <th id="T_6af1d_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_6af1d_row1_col0" class="data row1 col0" >468</td>
#       <td id="T_6af1d_row1_col1" class="data row1 col1" >109</td>
#       <td id="T_6af1d_row1_col2" class="data row1 col2" >577</td>
#     </tr>
#     <tr>
#       <th id="T_6af1d_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_6af1d_row2_col0" class="data row2 col0" >549</td>
#       <td id="T_6af1d_row2_col1" class="data row2 col1" >342</td>
#       <td id="T_6af1d_row2_col2" class="data row2 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2.2 Both Sex and Pclass

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %%
# Pclass가 col
sns.factorplot(x='Sex', y='Survived', col='Pclass',data=df_train, saturation=.5,
              size=9, aspect=1)

# %%
# Pclass가 hue
sns.factorplot(x='Sex', y='Survived', hue='Pclass',data=df_train, saturation=.5,
              size=9, aspect=1)
