# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('/kaggle/input/titanic/train.csv')
df_test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='autumn')
# Out:
# <style type="text/css">
# #T_65043_row0_col0, #T_65043_row1_col1, #T_65043_row1_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_65043_row0_col1 {
#   background-color: #ff3100;
#   color: #f1f1f1;
# }
# #T_65043_row0_col2 {
#   background-color: #ff0b00;
#   color: #f1f1f1;
# }
# #T_65043_row1_col0 {
#   background-color: #ff0900;
#   color: #f1f1f1;
# }
# #T_65043_row2_col0 {
#   background-color: #ff9f00;
#   color: #000000;
# }
# #T_65043_row2_col1 {
#   background-color: #ff2000;
#   color: #f1f1f1;
# }
# #T_65043_row2_col2 {
#   background-color: #ff6f00;
#   color: #f1f1f1;
# }
# #T_65043_row3_col0, #T_65043_row3_col1, #T_65043_row3_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_65043_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65043_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_65043_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_65043_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_65043_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_65043_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_65043_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_65043_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_65043_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_65043_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_65043_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_65043_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_65043_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_65043_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_65043_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_65043_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_65043_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()
